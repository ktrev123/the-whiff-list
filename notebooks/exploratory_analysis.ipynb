# %% [markdown]
# # The Whiff List — Exploratory Data Analysis
#
# This notebook explores 2025 Statcast pitch data for qualified hitters (502+ AB).
#
# **Central question:** Should swing/whiff models be **league-wide** or **fit per player**?
#
# Running the analysis cell generates an interactive HTML report and opens it in your browser.
#
# **Prerequisite:** `python notebooks/statcast_pull.py`

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.exploratory_analysis import REPORT_FILE, run_eda

report_path = run_eda(open_browser=True)
print(f"Report saved to: {report_path}")

# %% [markdown]
# ## What's in the report
#
# - Feature correlation matrix (location, count, pitch physics vs swing/whiff)
# - Heterogeneity in swing, whiff, and chase rates across hitters
# - Monthly trends and pitch-type profiles
# - Spatial heatmaps (swing & whiff by zone)
# - **League vs per-player logistic models** on September holdout
# - Sample-size analysis: when personalization beats the league model
# - Modeling recommendations for The Whiff List
